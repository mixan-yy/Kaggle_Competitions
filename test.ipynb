# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_7e169_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7e169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e169_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7e169_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e169_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7e169_row0_col1" class="data row0 col1" >1983</td>
#     </tr>
#     <tr>
#       <th id="T_7e169_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e169_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7e169_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_7e169_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a5560 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best)

# %%
evaluate_model(best)
# Out:
#                                              Parameters
# nan_mode                                            Min
# eval_metric                                     Logloss
# iterations                                         1000
# sampling_frequency                              PerTree
# leaf_estimation_method                           Newton
# grow_policy                               SymmetricTree
# penalties_coefficient                                 1
# boosting_type                                     Plain
# model_shrink_mode                              Constant
# feature_border_type                        GreedyLogSum
# bayesian_matrix_reg                 0.10000000149011612
# force_unit_auto_pair_weights                      False
# l2_leaf_reg                                           3
# random_strength                                       1
# rsm                                                   1
# boost_from_average                                False
# ...
